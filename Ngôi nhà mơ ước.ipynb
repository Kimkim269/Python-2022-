# %%
# Nâng cấp ngôi nhà mơ ước
import turtle
pen = turtle.Turtle()
pen.pensize(2)
pen.pencolor("#3933FF") 
pen.penup()
pen.goto(-120, 0)
pen.pendown()

# Vẽ khung nhà
pen.pencolor('#F7FE2E')
pen.fillcolor('#F7FE2E')
pen.begin_fill()
pen.forward(200)
pen.right(90)
pen.forward(150)
pen.right(90)
pen.forward(200)
pen.right(90)
pen.forward(150)
pen.end_fill()

# Vẽ cửa chính
pen.penup()
pen.goto(-80, -150)
pen.pendown()
pen.pencolor('#D8D8D8')
pen.fillcolor('#D8D8D8')
pen.begin_fill()
pen.forward(120)
pen.right(90)
pen.forward(60)
pen.right(90)
pen.forward(120)
pen.end_fill()

# Vẽ cửa sổ
pen.penup()
pen.goto(5, -50)
pen.pendown()
pen.pencolor('#D8D8D8')
pen.fillcolor('#D8D8D8')
pen.begin_fill()
pen.forward(50)
pen.left(90)
pen.forward(50)
pen.left(90)
pen.forward(50)
pen.left(90)
pen.forward(50)
pen.end_fill()

#Vẽ mái nhà
pen.penup()
pen.goto(-120, 0)
pen.pendown()
pen.pencolor('#FE2E64')
pen.fillcolor('#FE2E64')
pen.begin_fill()
pen.right(120)
pen.forward(160)
pen.right(120)
pen.forward(160)
pen.end_fill()

# Vẽ ống khói
pen.penup()
pen.goto(5, 61)
pen.pendown()
pen.pencolor('#424242')
pen.fillcolor('#424242')
pen.begin_fill()
pen.left(150)
pen.forward(50)
pen.right(90)
pen.forward(25)
pen.right(90)
pen.forward(93)
pen.end_fill()

#Vẽ khói bay lên
pen.penup()
pen.goto(20, 130)
pen.pendown()
pen.pencolor('#424242')
pen.fillcolor('#424242')
pen.begin_fill()
khoi_1 = 15
pen.circle(khoi_1)
pen.end_fill()
pen.penup()
pen.goto(60, 180)
pen.pendown()
pen.pencolor('#848484')
pen.fillcolor('#848484')
pen.begin_fill()
khoi_2 = 10
pen.circle(khoi_2)
pen.end_fill()
pen.penup()
pen.goto(100, 230)
pen.pendown()
pen.pencolor('#D8D8D8')
pen.fillcolor('#D8D8D8')
pen.begin_fill()
khoi_3 = 5
pen.circle(khoi_3)
pen.end_fill()

#Cái cây thứ nhất
pen.penup()
pen.goto(-230, -230)
pen.pendown()
pen.right(185)
pen.pendown()
pen.pencolor('#0B610B')
pen.fillcolor('#0B610B')
pen.begin_fill()
pen.forward(50)
pen.left(275)
pen.forward(20)
pen.right(85)
pen.forward(50)
pen.right(95)
pen.forward(30)
pen.end_fill()
pen.penup()
pen.goto(-245, -180)
pen.pendown()
pen.pencolor('#04B45F')
pen.fillcolor('#04B45F')
pen.begin_fill()
pen.right(120)
pen.forward(60)
pen.right(120)
pen.forward(60)
pen.right(120)
pen.forward(60)
pen.end_fill()
pen.penup()
pen.goto(-235, -127)
pen.pendown()
pen.pencolor('#58FAAC')
pen.fillcolor('#58FAAC')
pen.begin_fill()
pen.right(120)
pen.forward(40)
pen.right(120)
pen.forward(40)
pen.right(120)
pen.forward(40)
pen.end_fill()
pen.penup()
pen.goto(-225, -90)
pen.pendown()
pen.pencolor('#81F781')
pen.fillcolor('#81F781')
pen.begin_fill()
pen.right(120)
pen.forward(20)
pen.right(120)
pen.forward(20)
pen.right(120)
pen.forward(20)
pen.end_fill()

# Cái cây thứ 2
pen.penup()
pen.goto(250, -230)
pen.pendown()
pen.pencolor('#0B610B')
pen.fillcolor('#0B610B')
pen.begin_fill()
pen.forward(30)
pen.right(95)
pen.forward(50)
pen.left(275)
pen.forward(20)
pen.right(85)
pen.forward(50)
pen.end_fill()
pen.penup()
pen.goto(185, -180)
pen.pendown()
pen.pencolor('#04B45F')
pen.fillcolor('#04B45F')
pen.begin_fill()
pen.left(85)
pen.forward(100)
pen.left(120)
pen.forward(100)
pen.left(120)
pen.forward(100)
pen.end_fill()
pen.penup()
pen.goto(270, -91)
pen.pendown()
pen.pencolor('#58FAAC')
pen.fillcolor('#58FAAC')
pen.begin_fill()
pen.right(60)
pen.forward(80)
pen.right(120)
pen.forward(80)
pen.right(120)
pen.forward(80)
pen.end_fill()
pen.penup()
pen.goto(250, -21)
pen.pendown()
pen.pencolor('#81F781')
pen.fillcolor('#81F781')
pen.begin_fill()
pen.right(120)
pen.forward(40)
pen.right(120)
pen.forward(40)
pen.right(120)
pen.forward(40)
pen.end_fill()
turtle.done()
